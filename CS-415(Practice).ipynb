# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/Shareddrives/Final/src
# Out:
# /content/drive/Shareddrives/Final/src

# %%
# !ls
# Out:
# data	   loss     model  option.py	template.py  Untitled.ipynb
# launch.py  main.py  optim  __pycache__	train.py     utils.py

# %%
# !python main.py --save_dir GOPRO_L1 --demo_input_dir /content/drive/Shareddrives/Final/Research/dataset/GOPRO_Large/test/new1 --demo_output_dir ../results/GOPRO_Large/test/new1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 7 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ===> Loading demo dataset: Demo
# Loading model from ../experiment/GOPRO_L1/models/model-1000.pt
# Loading optimizer from ../experiment/GOPRO_L1/optim/optim-1000.pt
# Loss function: 1*L1
# Metrics: PSNR,SSIM
# Loading loss record from ../experiment/GOPRO_L1/loss.pt
# ===> Initializing trainer
# results are saved in ../results/GOPRO_Large/test/new1
# |███████████████████████████████████████████████| 41/41 [11:10<00:00, 16.35s/it]

# %%
# !python main.py --save_dir GOPRO_L1 --dataset GOPRO_Large
# Out:
# Traceback (most recent call last):
#   File "main.py", line 4, in <module>
#     from option import args, setup, cleanup
#   File "/content/drive/Shareddrives/Final/src/option.py", line 175, in <module>
#     args_old = torch.load(argname)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 608, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 777, in _legacy_load
#     magic_number = pickle_module.load(f, **pickle_load_args)
# EOFError: Ran out of input
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/subprocess.py", line 1019, in wait
#     return self._wait(timeout=timeout)
#   File "/usr/lib/python3.7/subprocess.py", line 1653, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/usr/lib/python3.7/subprocess.py", line 1611, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# ...
